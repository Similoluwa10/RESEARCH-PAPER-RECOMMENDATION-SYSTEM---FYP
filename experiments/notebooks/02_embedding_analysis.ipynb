# %% [markdown]
# # Embedding Analysis
#
# This notebook analyzes paper embeddings generated by sentence transformers.
#
# ## Contents
# 1. Generate embeddings
# 2. Visualize embedding space (t-SNE/UMAP)
# 3. Analyze clustering
# 4. Compare embedding models

# %%
import sys
sys.path.insert(0, '../../packages/nlp')

import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

from src.embeddings import SentenceTransformerEmbedding

# %%
# Initialize embedding model
embedder = SentenceTransformerEmbedding('all-MiniLM-L6-v2')
print(f"Model: {embedder.model_name}")
print(f"Dimension: {embedder.dimension}")

# %%
# Sample texts for demonstration
sample_texts = [
    "Deep learning for code clone detection",
    "Neural networks for bug prediction",
    "TF-IDF based document similarity",
    "Code review practices in open source",
]

embeddings = embedder.encode(sample_texts)
print(f"Embeddings shape: {embeddings.shape}")

# %% [markdown]
# ## Visualize Embedding Space

# %%
# TODO: Add t-SNE/UMAP visualization
# - Reduce to 2D
# - Color by category/venue
# - Analyze clusters
